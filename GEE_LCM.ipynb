# %% [markdown]
# <a href="https://colab.research.google.com/github/heromiya/GEE-LCM/blob/master/GEE_LCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf GEE-LCM && git clone https://github.com/heromiya/GEE-LCM.git
# Out:
# Cloning into 'GEE-LCM'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 842 (delta 12), reused 9 (delta 4), pack-reused 815
# Receiving objects: 100% (842/842), 43.22 MiB | 9.46 MiB/s, done.
# Resolving deltas: 100% (310/310), done.
# Checking out files: 100% (700/700), done.

# %%
# !apt install spatialite-bin grass parallel
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# grass is already the newest version (7.4.0-1).
# parallel is already the newest version (20161222-1).
# spatialite-bin is already the newest version (4.3.0-2build1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !cd GEE-LCM && bash merge-trainingdata.sh
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Execution of <sh /content/GEE-LCM/pointize/LT05_L1TP_126046_20050511_2.sh> finished.
# Cleaning up temporary files...
# Creating new GRASS GIS location/mapset...
# Executing <sh /content/GEE-LCM/pointize/LT05_L1TP_126046_20050511_3.sh> ...
# Importing raster map <gt_LT05_L1TP_126046_20050511>...
#  100%
#  100%
# ...
#  100%
# Writing vector map <gt_LT05_L1TP_126046_20050511_3> ...
#  100%
# Building topology for vector map
# <gt_LT05_L1TP_126046_20050511_3@PERMANENT>...
# Registering primitives...
# 10000 primitives registered
# 10000 vertices registered
# Building areas...
#  100%
# 0 areas built
# 0 isles built
# Attaching islands...
# Attaching centroids...
#  100%
# Number of nodes: 0
# Number of primitives: 10000
# Number of points: 10000
# Number of lines: 0
# Number of boundaries: 0
# Number of centroids: 0
# Number of areas: 0
# Number of isles: 0
# Exporting 10000 features...
#  100%
# v.out.ogr complete. 10000 features (Point type) written to
# ...
